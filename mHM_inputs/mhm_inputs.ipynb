# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os

# %%
src_dir=r'W:\VUB\main_research\mHM\mhm-v5.11.1\test_domain\input\meteo\pre'

# %%
data=xr.open_dataset(os.path.join(src_dir,'pre.nc'))

# %%
var='pre'
data[var][0].plot()

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1826, xc: 6, yc: 9)
# Coordinates:
#   * time     (time) datetime64[ns] 1989-01-01 1989-01-02 ... 1993-12-31
#   * xc       (xc) float32 3.973e+06 3.997e+06 4.021e+06 ... 4.069e+06 4.093e+06
#   * yc       (yc) float32 2.952e+06 2.928e+06 2.904e+06 ... 2.784e+06 2.76e+06
#     lon      (yc, xc) float32 ...
#     lat      (yc, xc) float32 ...
# Data variables:
#     pre      (time, yc, xc) float64 ...
